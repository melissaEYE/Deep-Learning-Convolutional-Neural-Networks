# %% [markdown]
# # Model CIFAR 10 Data in Python

# %% [markdown]
# In this script, we'll model the CIFAR 10 image recognition dataset in python. The input is all set up for you, but its up to you to build the network.
#
# First we'll import all the libraries we'll need.

# %%
import numpy as np
import pandas as pd
import os
import tarfile
import tensorflow.keras 
from tensorflow.keras.datasets import cifar10

# %%
(train_x, train_y), (test_x, test_y) = cifar10.load_data()
train_y = tensorflow.keras.utils.to_categorical(train_y, 10)
test_y = tensorflow.keras.utils.to_categorical(test_y, 10)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# 170508288/170498071 [==============================] - 2s 0us/step

# %% [markdown]
# Now import all the Keras parts you need, and start building your network. We've included some for you.

# %%
train_x.shape
# Out:
# (50000, 32, 32, 3)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Conv2D, Dropout  
from tensorflow.keras.layers import AveragePooling2D, MaxPooling2D, BatchNormalization

# %% [markdown]
# Now build your network! Here are some tips:
# - The input shape is (3, 32, 32)
# - You'll want to use 2D layers (Conv2D, MaxPooling2D, etc.)
# - The kernel_size argument for 2D layers is a tuple like this (5, 5)
#
# So insead of kernel_size = 5 (in the example), you'll say kernel_size = (5, 5). This imput is still tunable.
#
# And finally - here is your canvas!

# %%
model = Sequential()

# %%
model.add(Conv2D(filters = 128, kernel_size = (2, 2),  input_shape = (32, 32, 3), data_format = 'channels_last'))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Dropout(0.2))
model.add(BatchNormalization())

model.add(Conv2D(filters = 128, kernel_size = (4, 4), data_format = 'channels_last'))
model.add(AveragePooling2D(pool_size = (2, 2)))
model.add(Dropout(0.2))
model.add(BatchNormalization())

model.add(Flatten())
model.add(Dense(units = 10, activation = 'softmax'))

# %%
model.compile(loss = 'categorical_crossentropy', 
              optimizer = tensorflow.keras.optimizers.Adadelta(), 
              metrics = ['accuracy'])

# %%
model.fit(train_x, train_y, epochs = 100, batch_size = 5)
# Out:
# Epoch 1/100
# 10000/10000 [==============================] - 390s 39ms/step - loss: 2.4775 - accuracy: 0.1946
# Epoch 2/100
# 10000/10000 [==============================] - 390s 39ms/step - loss: 2.1630 - accuracy: 0.2725
# Epoch 3/100
# 10000/10000 [==============================] - 389s 39ms/step - loss: 2.0414 - accuracy: 0.3074
# Epoch 4/100
# 10000/10000 [==============================] - 389s 39ms/step - loss: 1.9838 - accuracy: 0.3247
# Epoch 5/100
# 10000/10000 [==============================] - 389s 39ms/step - loss: 1.9274 - accuracy: 0.3396
# Epoch 6/100
# 10000/10000 [==============================] - 388s 39ms/step - loss: 1.8938 - accuracy: 0.3529
# Epoch 7/100
# 10000/10000 [==============================] - 387s 39ms/step - loss: 1.8602 - accuracy: 0.3598
# Epoch 8/100
# 10000/10000 [==============================] - 389s 39ms/step - loss: 1.8351 - accuracy: 0.3724
# Epoch 9/100
# 10000/10000 [==============================] - 389s 39ms/step - loss: 1.8108 - accuracy: 0.3793
# Epoch 10/100
# 10000/10000 [==============================] - 388s 39ms/step - loss: 1.7879 - accuracy: 0.3862
# Epoch 11/100
# 10000/10000 [==============================] - 387s 39ms/step - loss: 1.7747 - accuracy: 0.3904
# Epoch 12/100
# 10000/10000 [==============================] - 388s 39ms/step - loss: 1.7569 - accuracy: 0.3949
# Epoch 13/100
# 10000/10000 [==============================] - 387s 39ms/step - loss: 1.7382 - accuracy: 0.4040
# Epoch 14/100
# 10000/10000 [==============================] - 388s 39ms/step - loss: 1.7170 - accuracy: 0.4095
# Epoch 15/100
# 10000/10000 [==============================] - 386s 39ms/step - loss: 1.7090 - accuracy: 0.4116
# Epoch 16/100
# 10000/10000 [==============================] - 393s 39ms/step - loss: 1.6916 - accuracy: 0.4179
# Epoch 17/100
# 10000/10000 [==============================] - 393s 39ms/step - loss: 1.6809 - accuracy: 0.4227
# Epoch 18/100
# 10000/10000 [==============================] - 392s 39ms/step - loss: 1.6665 - accuracy: 0.4264
# Epoch 19/100
# 10000/10000 [==============================] - 392s 39ms/step - loss: 1.6555 - accuracy: 0.4310
# Epoch 20/100
# 10000/10000 [==============================] - 391s 39ms/step - loss: 1.6467 - accuracy: 0.4314
# Epoch 21/100
# 10000/10000 [==============================] - 390s 39ms/step - loss: 1.6326 - accuracy: 0.4376
# Epoch 22/100
# 10000/10000 [==============================] - 390s 39ms/step - loss: 1.6215 - accuracy: 0.4448
# Epoch 23/100
# 10000/10000 [==============================] - 389s 39ms/step - loss: 1.6143 - accuracy: 0.4396
# Epoch 24/100
# 10000/10000 [==============================] - 388s 39ms/step - loss: 1.5983 - accuracy: 0.4509
# Epoch 25/100
# 10000/10000 [==============================] - 389s 39ms/step - loss: 1.5901 - accuracy: 0.4520
# Epoch 26/100
# 10000/10000 [==============================] - 392s 39ms/step - loss: 1.5838 - accuracy: 0.4584
# Epoch 27/100
# 10000/10000 [==============================] - 391s 39ms/step - loss: 1.5787 - accuracy: 0.4562
# Epoch 28/100
# 10000/10000 [==============================] - 392s 39ms/step - loss: 1.5681 - accuracy: 0.4655
# Epoch 29/100
# 10000/10000 [==============================] - 390s 39ms/step - loss: 1.5610 - accuracy: 0.4660
# Epoch 30/100
# 10000/10000 [==============================] - 392s 39ms/step - loss: 1.5488 - accuracy: 0.4669
# Epoch 31/100
# 10000/10000 [==============================] - 394s 39ms/step - loss: 1.5425 - accuracy: 0.4690
# Epoch 32/100
# 10000/10000 [==============================] - 396s 40ms/step - loss: 1.5399 - accuracy: 0.4709
# Epoch 33/100
# 10000/10000 [==============================] - 395s 40ms/step - loss: 1.5290 - accuracy: 0.4740
# Epoch 34/100
# 10000/10000 [==============================] - 394s 39ms/step - loss: 1.5250 - accuracy: 0.4745
# Epoch 35/100
# 10000/10000 [==============================] - 394s 39ms/step - loss: 1.5178 - accuracy: 0.4778
# Epoch 36/100
# 10000/10000 [==============================] - 394s 39ms/step - loss: 1.5070 - accuracy: 0.4822
# Epoch 37/100
# 10000/10000 [==============================] - 394s 39ms/step - loss: 1.5045 - accuracy: 0.4824
# Epoch 38/100
# 10000/10000 [==============================] - 394s 39ms/step - loss: 1.4959 - accuracy: 0.4862
# Epoch 39/100
# 10000/10000 [==============================] - 395s 40ms/step - loss: 1.4898 - accuracy: 0.4888
# Epoch 40/100
# 10000/10000 [==============================] - 397s 40ms/step - loss: 1.4867 - accuracy: 0.4885
# Epoch 41/100
# 10000/10000 [==============================] - 395s 40ms/step - loss: 1.4834 - accuracy: 0.4909
# Epoch 42/100
# 10000/10000 [==============================] - 394s 39ms/step - loss: 1.4757 - accuracy: 0.4921
# Epoch 43/100
# 10000/10000 [==============================] - 393s 39ms/step - loss: 1.4665 - accuracy: 0.4959
# Epoch 44/100
# 10000/10000 [==============================] - 393s 39ms/step - loss: 1.4627 - accuracy: 0.4988
# Epoch 45/100
# 10000/10000 [==============================] - 394s 39ms/step - loss: 1.4633 - accuracy: 0.4983
# Epoch 46/100
# 10000/10000 [==============================] - 392s 39ms/step - loss: 1.4588 - accuracy: 0.5007
# Epoch 47/100
# 10000/10000 [==============================] - 379s 38ms/step - loss: 1.4530 - accuracy: 0.5025
# Epoch 48/100
# 10000/10000 [==============================] - 380s 38ms/step - loss: 1.4430 - accuracy: 0.5046
# Epoch 49/100
# 10000/10000 [==============================] - 379s 38ms/step - loss: 1.4422 - accuracy: 0.5061
# Epoch 50/100
# 10000/10000 [==============================] - 379s 38ms/step - loss: 1.4396 - accuracy: 0.5081
# Epoch 51/100
# 10000/10000 [==============================] - 380s 38ms/step - loss: 1.4336 - accuracy: 0.5075
# Epoch 52/100
# 10000/10000 [==============================] - 379s 38ms/step - loss: 1.4295 - accuracy: 0.5089
# Epoch 53/100
# 10000/10000 [==============================] - 379s 38ms/step - loss: 1.4275 - accuracy: 0.5104
# Epoch 54/100
# 10000/10000 [==============================] - 376s 38ms/step - loss: 1.4218 - accuracy: 0.5137
# Epoch 55/100
# 10000/10000 [==============================] - 378s 38ms/step - loss: 1.4270 - accuracy: 0.5116
# Epoch 56/100
# 10000/10000 [==============================] - 380s 38ms/step - loss: 1.4159 - accuracy: 0.5149
# Epoch 57/100
# 10000/10000 [==============================] - 380s 38ms/step - loss: 1.4079 - accuracy: 0.5172
# Epoch 58/100
# 10000/10000 [==============================] - 380s 38ms/step - loss: 1.4041 - accuracy: 0.5190
# Epoch 59/100
# 10000/10000 [==============================] - 381s 38ms/step - loss: 1.4020 - accuracy: 0.5183
# Epoch 60/100
# 10000/10000 [==============================] - 380s 38ms/step - loss: 1.3990 - accuracy: 0.5202
# Epoch 61/100
# 10000/10000 [==============================] - 379s 38ms/step - loss: 1.3993 - accuracy: 0.5176
# Epoch 62/100
# 10000/10000 [==============================] - 380s 38ms/step - loss: 1.3995 - accuracy: 0.5199
# Epoch 63/100
#  6367/10000 [==================>...........] - ETA: 2:18 - loss: 1.4001 - accuracy: 0.5182

# %%
score = model.evaluate(test_x, test_y)
print('\nloss is: ' + str(score[0]))
print('accuracy is: ' + str(score[1]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c0974924288f> in <module>()
# ----> 1 score = model.evaluate(test_x, test_y)
#       2 print('\nloss is: ' + str(score[0]))
#       3 print('accuracy is: ' + str(score[1]))
#
# NameError: name 'model' is not defined
